# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_parquet('yellow_tripdata_2021-01.parquet')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
# ...

# %%
pd.to_datetime(df.tpep_pickup_datetime)
# Out:
# 0         2021-01-01 00:30:10
# 1         2021-01-01 00:51:20
# 2         2021-01-01 00:43:30
# 3         2021-01-01 00:15:48
# 4         2021-01-01 00:31:49
#                   ...
# 1369764   2021-01-31 23:03:00
# 1369765   2021-01-31 23:29:00
# 1369766   2021-01-31 23:25:00
# 1369767   2021-01-31 23:01:06
# 1369768   2021-01-31 23:08:29
# Name: tpep_pickup_datetime, Length: 1369769, dtype: datetime64[us]

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi') #root:root --> username and password/dB name

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df,name='yellow_taxi',con=engine))
# Out:
# CREATE TABLE yellow_taxi (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df.shape
# Out:
# (1369769, 19)

# %%
df_new = df[0:100000] #or use iterator:: pd.read_csv('filename',iterator=True,chunksize = 100000)

# %%
df_new
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52              3.0
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45              2.0
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22              2.0
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37              2.0
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44              5.0
#
# ...

# %%
df_new.to_sql(name='yellow_taxi',con=engine,if_exists = 'append')
# Out:
# 1000

# %%
query = """ 

SELECT * FROM yellow_taxi

"""

# you can also query from the pandas rather than pgcli. It is better this way 



pd.read_sql(query, con=engine)
# Out:
#         index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1           1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2           2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3           3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4           4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ...       ...       ...                  ...                   ...
# 199995  99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52
# 199996  99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45
# 199997  99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22
# 199998  99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37
# 199999  99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44
#
#         passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                   1.0           2.10         1.0                  N
# ...
